# %% [raw]
# LLN
# CLT

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.random.uniform(0, 10, 10000)
b = np.random.uniform(0, 10, 10000)
c = np.random.uniform(0, 10, 10000)

# %%
sns.histplot(a)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(b)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(a+b)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(a+b+c)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
x = np.random.chisquare(4,10000)
y = np.random.chisquare(4,10000)
z = np.random.chisquare(4,10000)

# %%
sns.histplot(x)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(x+y+z)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
f = np.random.pareto(4,10000)
g = np.random.pareto(4,10000)
h = np.random.pareto(4,10000)

# %%
sns.histplot(f)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(f+g+h)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
X = np.random.normal(10000)
Y = np.random.normal(10000)

# %%
from scipy import stats

# %%
X = stats.norm.rvs(size=1000)
Y = stats.norm.rvs(size=1000)

# %%
stats.pearsonr(X,Y)
# the second number is p-value. It can be interpreted as the probability to observe a 
# correlation that extreme in the sample
# Out:
# (0.05128732911127516, 0.10504207421567326)
